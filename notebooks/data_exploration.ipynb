# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/Data Science/Project 4/Project 4 Team 3/data/'
df = pd.read_csv(data_path + 'data_label_encoded.csv')
df.head()
# Out:
#       ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0    A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1    A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172394
# 2  A-432         2  2016-02-24 10:20:40  2016-02-24 16:20:40  41.475800
# 3  A-435         2  2016-02-24 10:49:54  2016-02-24 16:49:54  41.964290
# 4  A-436         2  2016-02-24 11:14:18  2016-02-24 17:14:18  41.282993
#
#    Start_Lng    End_Lat    End_Lng  Distance  \
# 0  -83.09286  40.112060 -83.031870     3.230
# 1  -84.49279  39.170475 -84.501800     0.500
# 2  -81.66036  41.483380 -81.662810     0.539
# 3  -83.35018  41.964290 -83.350180     0.000
# 4  -83.63893  41.283092 -83.638885     0.007
#
#                                          Description  ... Start_Time_Year  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...            2016
# 1                 At Mitchell Ave/Exit 6 - Accident.  ...            2016
# ...

# %% [markdown]
# #Severity dfs and graph font sizes

# %%
df_sev1 = df[df['Severity'] == 1]
df_sev2 = df[df['Severity'] == 2]
df_sev3 = df[df['Severity'] == 3]
df_sev4 = df[df['Severity'] == 4]

# %%
#graph font sizes from eve project 3
SMALL_SIZE = 20
MEDIUM_SIZE = 25
BIGGER_SIZE = 40

# Set font sizes individually. For example, you may want the title
# to be very big, but the axes labels to be only medium size.
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# #Plot duration minutes for each severity

# %%
col = 'Duration_Minutes'
plt.figure()
plt.boxplot([df_sev1[col], df_sev2[col], df_sev3[col], df_sev4[col]], showfliers=False)
plt.title(col + " (how long traffic was impacted)")
plt.show()

# %% [markdown]
# #Plot distance for each severity

# %%
col = 'Distance'
plt.figure()
plt.boxplot([df_sev1[col], df_sev2[col], df_sev3[col], df_sev4[col]], showfliers=False)
plt.title(col + " (miles of road affected)")
plt.show()

# %% [markdown]
# #Plot description keywords for each severity

# %%
col = 'Desc_Close'
plt.figure()
plt.hist([df_sev1[col], df_sev2[col], df_sev3[col], df_sev4[col]])
plt.title(col)
plt.show()

# %%
desc_cols = ['Desc_Close', 'Desc_Block', 'Desc_Construction', 'Desc_Accident', 'Desc_Traffic']

#zeros = [df[column].value_counts()[0] for column in desc_cols]
ones = [df[column].value_counts()[1] for column in desc_cols]
n = len(desc_cols)
#plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
plt.bar(np.arange(n)+0.1, ones, width=0.2, label='1')
plt.xticks(np.arange(n), desc_cols)
plt.legend()
plt.show()

# %%
desc_cols = ['Desc_Close', 'Desc_Block', 'Desc_Construction', 'Desc_Accident', 'Desc_Traffic']

#zeros = [df[column].value_counts()[0] for column in desc_cols]
ones = [df_sev1[column].value_counts()[1] for column in desc_cols]
n = len(desc_cols)
#plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
plt.bar(np.arange(n)+0.1, ones, width=0.2, label='1')
plt.xticks(np.arange(n), desc_cols)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1fd8a4978e9d> in <cell line: 4>()
#       2
#       3 #zeros = [df[column].value_counts()[0] for column in desc_cols]
# ----> 4 ones = [df_sev1[column].value_counts()[1] for column in desc_cols]
#       5 n = len(desc_cols)
#       6 #plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
#
# <ipython-input-15-1fd8a4978e9d> in <listcomp>(.0)
#       2
#       3 #zeros = [df[column].value_counts()[0] for column in desc_cols]
# ----> 4 ones = [df_sev1[column].value_counts()[1] for column in desc_cols]
#       5 n = len(desc_cols)
#       6 #plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     976
#     977         if is_integer(key) and self.index._should_fallback_to_positional:
# ...

# %%
desc_cols = ['Desc_Close', 'Desc_Block', 'Desc_Construction', 'Desc_Accident', 'Desc_Traffic']

#zeros = [df[column].value_counts()[0] for column in desc_cols]
ones = [df_sev2[column].value_counts()[1] for column in desc_cols]
n = len(desc_cols)
#plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
plt.bar(np.arange(n)+0.1, ones, width=0.2, label='1')
plt.xticks(np.arange(n), desc_cols)
plt.legend()
plt.show()

# %%
desc_cols = ['Desc_Close', 'Desc_Block', 'Desc_Construction', 'Desc_Accident', 'Desc_Traffic']

#zeros = [df[column].value_counts()[0] for column in desc_cols]
ones = [df_sev3[column].value_counts()[1] for column in desc_cols]
n = len(desc_cols)
#plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
plt.bar(np.arange(n)+0.1, ones, width=0.2, label='1')
plt.xticks(np.arange(n), desc_cols)
plt.legend()
plt.show()

# %%
desc_cols = ['Desc_Close', 'Desc_Block', 'Desc_Construction', 'Desc_Accident', 'Desc_Traffic']

#zeros = [df[column].value_counts()[0] for column in desc_cols]
ones = [df_sev4[column].value_counts()[1] for column in desc_cols]
n = len(desc_cols)
#plt.bar(np.arange(n)-0.1, zeros, width=0.2, label='0')
plt.bar(np.arange(n)+0.1, ones, width=0.2, label='1')
plt.xticks(np.arange(n), desc_cols)
plt.legend()
plt.show()

# %% [markdown]
# #Misc

# %%
col = 'Severity'
plt.figure()
plt.hist([df_sev1['Sunrise_Sunset'], df_sev3['Sunrise_Sunset'], df_sev4['Sunrise_Sunset']])
plt.title(col)
plt.show()

# %%
len(df['State'].unique())
# Out:
# 49

# %%
df['State'].unique()
#missing Alaska AK
# Out:
# array(['OH', 'IN', 'KY', 'WV', 'PA', 'MI', 'CA', 'MN', 'LA', 'NE', 'MO',
#        'IA', 'ND', 'CO', 'KS', 'TX', 'WI', 'OK', 'WY', 'SD', 'MS', 'AR',
#        'IL', 'MA', 'RI', 'ME', 'NY', 'TN', 'FL', 'MD', 'NC', 'GA', 'VA',
#        'CT', 'NJ', 'DE', 'NH', 'SC', 'VT', 'DC', 'AL', 'MT', 'ID', 'UT',
#        'AZ', 'NM', 'NV', 'WA', 'OR'], dtype=object)

# %%
df['Roundabout'].value_counts()
# Out:
# False    2207224
# True         101
# Name: Roundabout, dtype: int64

# %%
print(df_sev1['Precipitation'].mean())
print(df_sev2['Precipitation'].mean())
print(df_sev3['Precipitation'].mean())
print(df_sev4['Precipitation'].mean())
# Out:
# 0.005489896417048734
# 0.005594623433759101
# 0.00940948783055676
# 0.00558915402698612

# %%
r2 = df.corr() ** 2

# %%
r2.iloc[1,:]
# Out:
# Severity           7.437046e-03
# Start_Lat          1.000000e+00
# Start_Lng          3.264835e-02
# End_Lat            9.999912e-01
# End_Lng            3.264681e-02
# Distance           7.094135e-03
# Temperature        2.415835e-01
# Wind_Chill         2.467020e-01
# Humidity           1.159612e-05
# Pressure           8.884139e-02
# Visibility         1.188852e-02
# Wind_Speed         3.368188e-04
# Precipitation      1.296813e-04
# Amenity            8.786735e-05
# Bump               6.635569e-08
# Crossing           1.088103e-02
# Give_Way           1.332260e-04
# Junction           3.746058e-03
# No_Exit            3.371604e-04
# Railway            8.695637e-07
# Roundabout         2.833685e-05
# Station            1.544845e-02
# Stop               1.130409e-04
# Traffic_Calming    1.379745e-05
# Traffic_Signal     3.498290e-03
# Turning_Loop                NaN
# Name: Start_Lat, dtype: float64
